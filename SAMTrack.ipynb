# %% [markdown]
# <a href="https://colab.research.google.com/github/7788po/colab-notebook/blob/main/SAMTrack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone the SAMTrack repository using Git

# %%
# !git clone https://github.com/z-x-yang/Segment-and-Track-Anything.git
# %cd /content/Segment-and-Track-Anything
# Out:
# Cloning into 'Segment-and-Track-Anything'...
# remote: Enumerating objects: 645, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 645 (delta 143), reused 129 (delta 129), pack-reused 480
# Receiving objects: 100% (645/645), 230.30 MiB | 15.34 MiB/s, done.
# Resolving deltas: 100% (304/304), done.
# /content/Segment-and-Track-Anything

# %% [markdown]
# # Install dependencies

# %%
# !bash script/install.sh
# Out:
# Obtaining file:///content/Segment-and-Track-Anything/sam
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for segment-anything
# ...
# /content/Segment-and-Track-Anything
# Obtaining GroundingDINO from git+https://github.com/IDEA-Research/GroundingDINO.git@main#egg=GroundingDINO
#   Cloning https://github.com/IDEA-Research/GroundingDINO.git (to revision main) to ./src/groundingdino
#   Running command git clone --filter=blob:none --quiet https://github.com/IDEA-Research/GroundingDINO.git /content/Segment-and-Track-Anything/src/groundingdino
#   Resolved https://github.com/IDEA-Research/GroundingDINO.git to commit 60d796825e1266e56f7e4e9e00e88de662b67bd3
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 77.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Download ckpt

# %%
# !mkdir ./ckpt
# !bash script/download_ckpt.sh
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QoChMkTVxdYZ_eBlZhK2acq9KMQZccPJ
# To: /content/Segment-and-Track-Anything/ckpt/R50_DeAOTL_PRE_YTB_DAV.pth
# 100% 237M/237M [00:02<00:00, 97.9MB/s]
# --2023-10-08 11:04:04--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.224.250.114, 13.224.250.75, 13.224.250.108, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.224.250.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 375042383 (358M) [binary/octet-stream]
# Saving to: ‘./ckpt/sam_vit_b_01ec64.pth’
#
# sam_vit_b_01ec64.pt 100%[===================>] 357.67M   153MB/s    in 2.3s
#
# ...

# %% [markdown]
# # Run WebUI

# %%
# !pip install gradio
# Out:
# ...
#   Using cached gradio-3.47.1-py3-none-any.whl (20.3 MB)
# ...
#   Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# ...
#   Using cached fastapi-0.103.2-py3-none-any.whl (66 kB)
# ...
#   Using cached ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached gradio_client-0.6.0-py3-none-any.whl (298 kB)
# ...
#   Using cached httpx-0.25.0-py3-none-any.whl (75 kB)
# ...
#   Using cached orjson-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# ...
#   Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# ...
#   Using cached websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !python app.py
# Out:
# /content/Segment-and-Track-Anything/app.py:481: GradioDeprecationWarning: 'scale' value should be an integer. Using 0.5 will cause issues.
#   with gr.Column(scale=0.5):
# /content/Segment-and-Track-Anything/app.py:485: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   input_video = gr.Video(label='Input video').style(height=550)
# /content/Segment-and-Track-Anything/app.py:490: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   input_img_seq = gr.File(label='Input Image-Seq').style(height=550)
# /content/Segment-and-Track-Anything/app.py:490: GradioDeprecationWarning: Unknown style parameter: height
#   input_img_seq = gr.File(label='Input Image-Seq').style(height=550)
# /content/Segment-and-Track-Anything/app.py:491: GradioDeprecationWarning: 'scale' value should be an integer. Using 0.25 will cause issues.
#   with gr.Column(scale=0.25):
# ...
